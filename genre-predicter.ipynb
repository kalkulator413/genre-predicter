# %%
#GENRES:
# FOLK -> 'Nick Drake', 'Pink Moon' | 'Elliot Smith', 'Either/Or' | 'Sufjan Stevens', 'Carrie & Lowell' | 'Fleet Foxes', 'Self Titled' | 'Sun Kil Moon', 'Ghosts of the Great Highway'
# ROCK -> 'Radiohead', 'Ok Computer' | 'Pink Floyd', 'Wish You Were Here' | 'Judas Priest', 'Painkiller' | 'Joy Division', 'Unknown Pleasures' | 'The Strokes', 'Is This It'
# POP -> 'Beach Boys', 'Pet Sounds' | 'Kate Bush', 'Hounds of Love' | 'Carly Rae Jepsen', 'Emotion' | 'Belle and Sebastian', 'If You're Feeling Sinister' | 'Bjork', 'Vespertine'
# HIP-HOP -> 'Kendrick Lamar', 'To Pimp a Butterfly' | 'Madvillian', 'Madvilliany' | 'Nas', 'Illmatic' | 'Kanye West', 'My Beautiful Dark Twisted Fantasy' | 'Travis Scott', 'Rodeo'
# EXPERIMENTAL -> 'Swans', 'Soundtracks for the Blind' | 'Xiu Xiu', 'A Promise' | 'Death Grips', 'The Money Store' | 'Injury Reserve', 'By the Time I Get to Phoenix' | 'Lingua Ignota', 'Sinner Get Ready'
# ELECTRONIC -> 'Aphex Twin', 'Selected Ambient Works 85-92' | 'Sweet Trip', 'Velocity : Design : Comfort' | 'Boards of Canada', 'Music Has the Right to Children' | 'Burial', 'Untrue' | 'Flying Lotus', 'Cosmogramma'

# %%
from api_info import *
import torch
import torch.nn as nn
import numpy as np
import pickle

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# genres = ['folk', 'rock', 'pop', 'hip-hop', 'experimental', 'electronic']
genres = ['folk', 'pop', 'hip-hop']

# albums = [
#     [('Nick Drake', 'Pink Moon'), 'folk'],
#     [('Nick Drake', 'Five Leaves Left'), 'folk'],
#     [('Elliot Smith', 'Either/Or'), 'folk'],
#     [('Sufjan Stevens', 'Carrie & Lowell'), 'folk'],
#     [('Fleet Foxes', 'Fleet Foxes'), 'folk'],
#     [('Fleet Foxes', 'Helplessness Blues'), 'folk'],
#     [('Sun Kil Moon', 'Ghosts of the Great Highway'), 'folk'],
#     [('Neutral Milk Hotel', 'In the Aeroplane Over the Sea'), 'folk'],
#     [('The Microphones', 'The Glow, Pt. 2'), 'folk'],
#     [('Mount Eerie', 'A Crow Looked At Me'), 'folk'],
#     [('Big Thief', 'Dragon New Warm Mountain I Believe in You'), 'folk'],

#     [('Radiohead', 'Ok Computer'), 'rock'],
#     [('Pink Floyd', 'Wish You Were Here'), 'rock'],
#     [('Judas Priest', 'Painkiller'), 'rock'],
#     [('Joy Division', 'Unknown Pleasures'), 'rock'],
#     [('The Strokes', 'Is This It'), 'rock'],
#     [('my bloody valentine', 'Loveless'), 'rock'],
#     [('The Beatles', 'Abbey Road'), 'rock'],
#     [('David Bowie', 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars'), 'rock'],
#     [('Talking Heads', 'Remain in Light'), 'rock'],
#     [('Godspeed You! Black Emperor','Lift Your Skinny Fists Like Antennas to Heaven'), 'rock'],
#     [('Slint', 'Spiderland'), 'rock'],


#     [('Beach Boys', 'Pet Sounds'), 'pop'],
#     [('Kate Bush', 'Hounds of Love'), 'pop'],
#     [('Carly Rae Jepsen', 'Emotion'), 'pop'],
#     [('Belle and Sebastian', 'If Youre Feeling Sinister'), 'pop'],
#     # [('Bjork', 'Vespertine'), 'pop'],
#     [('Taylor Swift', '1989'), 'pop'],
#     [('The Beatles', 'Abbey Road'), 'pop'],
#     [('David Bowie', 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars'), 'pop'],
#     [('Bjork', 'Post'), 'pop'],
#     [('Bjork', 'Debut'), 'pop'],
#     [('New Order', 'Power Corruption and Lies'), 'pop'],
#     [('Carly Rae Jepsen', 'Dedicated'), 'pop'],
#     [('Taylor Swift', 'Red'), 'pop'],

#     [('Kendrick Lamar', 'To Pimp a Butterfly'), 'hip-hop'],
#     [('Kendrick Lamar', 'good kid, m.A.A.d city'), 'hip-hop'],
#     [('Madvillain', 'Madvillainy'), 'hip-hop'],
#     [('Nas', 'Illmatic'), 'hip-hop'],
#     [('Nas', 'Magic'), 'hip-hop'],
#     [('Kanye West', 'My Beautiful Dark Twisted Fantasy'), 'hip-hop'],
#     [('Kanye West', 'The College Dropout'), 'hip-hop'],
#     [('Travis Scott', 'Rodeo'), 'hip-hop'],
#     [('Playboi Carti', 'Die Lit'), 'hip-hop'],
#     [('Death Grips', 'The Money Store'), 'hip-hop'],

#     [('Swans', 'Soundtracks for the Blind'), 'experimental'],
#     [('Xiu Xiu', 'A Promise'), 'experimental'],
#     [('Death Grips', 'The Money Store'), 'experimental'],
#     [('Injury Reserve', 'By the Time I Get to Phoenix'), 'experimental'],
#     [('Lingua Ignota', 'Sinner Get Ready'), 'experimental'],

#     [('Aphex Twin', 'Selected Ambient Works 85-92'), 'electronic'],
#     [('Sweet Trip', 'Velocity: Design: Comfort'), 'electronic'],
#     [('Boards of Canada', 'Music Has the Right to Children'), 'electronic'],
#     [('Burial', 'Untrue'), 'electronic'],
#     [('Flying Lotus', 'Cosmogramma'), 'electronic']
# ]

albums = [
    [('Nick Drake', 'Pink Moon'), 'folk'],
    [('Nick Drake', 'Five Leaves Left'), 'folk'],
    [('Elliot Smith', 'Either/Or'), 'folk'],
    [('Sufjan Stevens', 'Carrie & Lowell'), 'folk'],
    [('Fleet Foxes', 'Fleet Foxes'), 'folk'],
    [('Fleet Foxes', 'Helplessness Blues'), 'folk'],
    [('Sun Kil Moon', 'Ghosts of the Great Highway'), 'folk'],
    [('Neutral Milk Hotel', 'In the Aeroplane Over the Sea'), 'folk'],
    [('The Microphones', 'The Glow, Pt. 2'), 'folk'],
    [('Mount Eerie', 'A Crow Looked At Me'), 'folk'],
    [('Big Thief', 'Dragon New Warm Mountain I Believe in You'), 'folk'],

    # [('Radiohead', 'Ok Computer'), 'rock'],
    # [('Pink Floyd', 'Wish You Were Here'), 'rock'],
    # [('Judas Priest', 'Painkiller'), 'rock'],
    # [('Joy Division', 'Unknown Pleasures'), 'rock'],
    # [('The Strokes', 'Is This It'), 'rock'],
    # [('my bloody valentine', 'Loveless'), 'rock'],
    # [('The Beatles', 'Abbey Road'), 'rock'],
    # [('David Bowie', 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars'), 'rock'],
    # [('Talking Heads', 'Remain in Light'), 'rock'],
    # [('Godspeed You! Black Emperor','Lift Your Skinny Fists Like Antennas to Heaven'), 'rock'],
    # [('Slint', 'Spiderland'), 'rock'],


    [('Beach Boys', 'Pet Sounds'), 'pop'],
    [('Kate Bush', 'Hounds of Love'), 'pop'],
    [('Carly Rae Jepsen', 'Emotion'), 'pop'],
    [('Belle and Sebastian', 'If Youre Feeling Sinister'), 'pop'],
    # [('Bjork', 'Vespertine'), 'pop'],
    [('Taylor Swift', '1989'), 'pop'],
    [('The Beatles', 'Abbey Road'), 'pop'],
    [('David Bowie', 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars'), 'pop'],
    [('Bjork', 'Post'), 'pop'],
    [('Bjork', 'Debut'), 'pop'],
    [('New Order', 'Technique'), 'pop'],
    [('Carly Rae Jepsen', 'Dedicated'), 'pop'],
    [('Taylor Swift', 'Red'), 'pop'],
    [('Lorde', 'Melodrama'), 'pop'],
    [('Carly Rae Jepsen', 'Kiss'), 'pop'],
    [('Carly Rae Jepsen', 'Emotion Side B'), 'pop'],
    [('LOONA', '[X X]'), 'pop'],
    [('Charli XCX', 'Sucker'), 'pop'],

    [('Kendrick Lamar', 'To Pimp a Butterfly'), 'hip-hop'],
    [('Kendrick Lamar', 'good kid, m.A.A.d city'), 'hip-hop'],
    [('Madvillain', 'Madvillainy'), 'hip-hop'],
    [('Nas', 'Illmatic'), 'hip-hop'],
    [('Nas', 'Magic'), 'hip-hop'],
    [('Kanye West', 'My Beautiful Dark Twisted Fantasy'), 'hip-hop'],
    [('Kanye West', 'The College Dropout'), 'hip-hop'],
    [('Travis Scott', 'Rodeo'), 'hip-hop'],
    [('Travis Scott', 'Astroworld'), 'hip-hop'],
    [('Playboi Carti', 'Playboi Carti'), 'hip-hop'],
    [('Wu-Tang Clan', 'Enter The Wu-Tang (36 Chambers) [Expanded Edition]'), 'hip-hop'],
    [('Beastie Boys', 'Pauls Boutique'), 'hip-hop'],
    [('Outkast', 'Aquemini'), 'hip-hop'],
    [('Mos Def', 'Black on Both Sides'), 'hip-hop'],
    [('The Roots', 'Things Fall Apart'), 'hip-hop'],
    # [('Death Grips', 'The Money Store'), 'hip-hop'],

    # [('Swans', 'Soundtracks for the Blind'), 'experimental'],
    # [('Xiu Xiu', 'A Promise'), 'experimental'],
    # [('Death Grips', 'The Money Store'), 'experimental'],
    # [('Injury Reserve', 'By the Time I Get to Phoenix'), 'experimental'],
    # [('Lingua Ignota', 'Sinner Get Ready'), 'experimental'],

    # [('Aphex Twin', 'Selected Ambient Works 85-92'), 'electronic'],
    # [('Sweet Trip', 'Velocity: Design: Comfort'), 'electronic'],
    # [('Boards of Canada', 'Music Has the Right to Children'), 'electronic'],
    # [('Burial', 'Untrue'), 'electronic'],
    # [('Flying Lotus', 'Cosmogramma'), 'electronic']
]

# %%
data = []

for album in albums:
    # make a zero array of length genres ex [0, 0, 0, 0, 0, 1]
    # with the 1 indiciating which genre it is
    genre_array = np.zeros(len(genres))
    genre_array[genres.index(album[1])] = 1

    results = sp.search(q=f'artist:{album[0][0]} album:{album[0][1]}', type='album')
    album_id = results['albums']['items'][0]['id']
    tracks = sp.album_tracks(album_id)['items']

    for track in tracks:
        track_id = track['id']
        f = sp.audio_features(track_id)[0]
        song_data = np.array([
            f['danceability'], 
            f['energy'], 
            # f['loudness'], 
            f['speechiness'], 
            f['acousticness'], 
            f['instrumentalness'], 
            f['liveness'], 
            f['valence']#, 
            # f['tempo']
        ])
        data.append((song_data, genre_array))

# %%
print(data[5])

with open('data', 'wb') as f: 
    pickle.dump(data, f)
# Out:
# (array([0.67  , 0.311 , 0.0377, 0.846 , 0.0512, 0.119 , 0.243 ]), array([1., 0., 0.]))

# %%
with open('data', 'rb') as f: 
    data = pickle.load(f) 

np.random.shuffle(data)
print(data[:5])

print(len(data))
# Out:
# [(array([6.77e-01, 8.42e-01, 3.60e-01, 2.28e-01, 6.84e-04, 8.56e-01,
#        5.95e-01]), array([0., 0., 1.])), (array([7.17e-01, 7.90e-01, 2.00e-01, 3.30e-01, 1.25e-04, 5.18e-01,
#        3.71e-01]), array([0., 0., 1.])), (array([4.60e-01, 3.26e-01, 4.17e-02, 1.42e-01, 1.01e-05, 4.49e-02,
#        3.21e-01]), array([0., 1., 0.])), (array([6.82e-01, 3.45e-01, 7.40e-02, 8.63e-01, 3.34e-06, 1.00e-01,
#        4.85e-01]), array([1., 0., 0.])), (array([0.447 , 0.214 , 0.0427, 0.929 , 0.735 , 0.115 , 0.141 ]), array([1., 0., 0.]))]
# 634

# %%
model = nn.Sequential(
  nn.Linear(7, 128),
  nn.ReLU(),
  nn.Linear(128, 128),
  nn.ReLU(),
  nn.Linear(128, 3),
  nn.Softmax(-1)
  # nn.Sigmoid()
)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1)

# %%
for epoch in range(1, 51):
  losses = []
  for x, y in data:
    x = torch.tensor(x).reshape(7).float()
    y = torch.tensor(y).reshape(3).float()

    guess = model(x)
    # print(x, y, guess)

    loss = nn.functional.huber_loss(guess, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


    losses.append(loss.item())
  if epoch % 5 == 0:
    print("LOSS", np.mean(losses))
# Out:
# LOSS 0.05435942121996778
# LOSS 0.05109593466863094
# LOSS 0.049275109442634524
# LOSS 0.04789171677153286
# LOSS 0.04682086357162086
# LOSS 0.04576135670794877
# LOSS 0.04470882263690052
# LOSS 0.04383120480695777
# LOSS 0.04284999851908153
# LOSS 0.04196058045161127

# %%
def get_genre(name, artist):
  results = sp.search(q="track:" + name + " artist:" + artist, type="track")
  track_id = results['tracks']['items'][0]['id']

  f = sp.audio_features(track_id)[0]
  song = np.array([
      f['danceability'], 
      f['energy'], 
      # f['loudness'], 
      f['speechiness'], 
      f['acousticness'], 
      f['instrumentalness'], 
      f['liveness'], 
      f['valence']#, 
      # f['tempo']
  ])
  song = torch.tensor(song).reshape(7).float()

  value = model(song)
  return (f'{name} by {artist}', value)
  return value

# test_songs = [
#     # ("New Slaves", 'Kanye West'),
#     # ("Self Control", 'Frank Ocean'),
#     # ("Let Down", 'Radiohead'),
#     # ("Blow Out", 'Radiohead'),
#     # ('Only Shallow', 'my bloody valentine'),
#     # ('Heaven or Las Vegas', 'Cocteau Twins'),
#     # ('Fell in Love (At the Water)', 'Candy Claws'),
#     # ('Chocolate Matter', 'Sweet Trip'),
#     # ('Bloodhail', 'Have a Nice Life'),
#     # ('Vapour Trail', 'Ride'),
#     # ('Hell of a Life', 'Kanye West'),
#     # ('Blank Space', 'Taylor Swift'),
#     # ('Alison', 'Slowdive'),
#     # ('Sometimes', 'my bloody valentine'),
#     # ('Beautiful World', 'Parannoul'),
#     ('Modern Love Stories', 'Beach House'),
#     ('Wesley\'s Theory', 'Kendrick Lamar'),
#     ('Pictures of You', 'The Cure'),
#     ('Blood Section', 'Swans'),
#     ('Ring a Bell', 'Death Grips'),
#     ('Total Trash', 'Sonic Youth'),
#     ('The Scientist', 'Coldplay'),
#     ('Territorial Pissings', 'Nirvana'),
#     ('Hard to Explain', 'The Strokes'),
#     ('Snow Globes', 'Black Country, New Road')
# ]

# %%
test_songs = [
  ('Pink Moon', 'Nick Drake'),
  ('Montezuma', 'Fleet Foxes'),
  ('wesleys Theory', 'Kendrick Lamar'),
  ('Aquemini', 'Outkast'),
  ('Blank Space', "Taylor Swift"),
  ('Gimmie Love', "Carly Rae Jepsen"),
  ('But the Regrets Are Killing Me', 'American Football')
]
tests = [get_genre(x[0], x[1]) for x in test_songs]
for test in tests:
  print(test)
# Out:
# ('Pink Moon by Nick Drake', tensor([0.8468, 0.1363, 0.0169], grad_fn=<SoftmaxBackward0>))
# ('Montezuma by Fleet Foxes', tensor([0.7326, 0.2358, 0.0317], grad_fn=<SoftmaxBackward0>))
# ('wesleys Theory by Kendrick Lamar', tensor([0.0012, 0.0053, 0.9935], grad_fn=<SoftmaxBackward0>))
# ('Aquemini by Outkast', tensor([2.0954e-05, 1.2414e-04, 9.9985e-01], grad_fn=<SoftmaxBackward0>))
# ('Blank Space by Taylor Swift', tensor([0.0072, 0.8380, 0.1549], grad_fn=<SoftmaxBackward0>))
# ('Gimmie Love by Carly Rae Jepsen', tensor([0.0126, 0.8692, 0.1182], grad_fn=<SoftmaxBackward0>))
# ('But the Regrets Are Killing Me by American Football', tensor([0.1885, 0.7597, 0.0518], grad_fn=<SoftmaxBackward0>))
