# %%
from api_info import *
import torch
import torch.nn as nn
import numpy as np
import pickle

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
genres = ['folk', 'rock', 'pop', 'hip-hop', 'electronic']

albums = [
    [('Nick Drake', 'Pink Moon'), 'folk'],
    [('Nick Drake', 'Five Leaves Left'), 'folk'],
    [('Elliot Smith', 'Either/Or'), 'folk'],
    [('Sufjan Stevens', 'Carrie & Lowell'), 'folk'],
    [('Sufjan Stevens', 'A Beginners Mind'), 'folk'],
    [('Fleet Foxes', 'Fleet Foxes'), 'folk'],
    [('Fleet Foxes', 'Helplessness Blues'), 'folk'],
    [('Fleet Foxes', 'Sun Giant'), 'folk'],
    [('Sun Kil Moon', 'Ghosts of the Great Highway'), 'folk'],
    [('Neutral Milk Hotel', 'In the Aeroplane Over the Sea'), 'folk'],
    [('The Microphones', 'The Glow, Pt. 2'), 'folk'],
    [('Mount Eerie', 'A Crow Looked At Me'), 'folk'],
    [('Big Thief', 'Dragon New Warm Mountain I Believe in You'), 'folk'],
    [('Bob Dylan', 'Bringing It All Back Home'), 'folk'],
    [('Leonard Cohen', 'Songs of Love'), 'folk'],
    [('Comus', 'First Utterance'), 'folk'],
    [('Current 93', 'Thunder Perfect Mind'), 'folk'],
    [('Bob Dylan', 'The Freewheelin Bob Dylan'), 'folk'],
    [('Bon Iver', 'For Emma, Forever Ago'), 'folk'],

    [('Led Zeppelin', 'Led Zeppelin'), 'rock'],
    [('Led Zeppelin', 'Led Zeppelin II'), 'rock'],
    [('Led Zeppelin', 'Led Zeppelin III'), 'rock'],
    [('Led Zeppelin', 'Led Zeppelin IV'), 'rock'],
    [('Arcade Fire', 'Funeral'), 'rock'],
    [('Judas Priest', 'Painkiller'), 'rock'],
    [('Radiohead', 'Ok Computer'), 'rock'],
    [('Pink Floyd', 'Wish You Were Here'), 'rock'],
    [('Pink Floyd', 'Dark Side of the Moon'), 'rock'],
    [('The Velvet Underground', 'The Velvet Underground & Nico'), 'rock'],
    [('The Velvet Underground', 'The Velvet Underground'), 'rock'],
    [('The Velvet Underground', 'White Light / White Heat'), 'rock'],
    [('King Crimson', 'In The Court of the Crimson King'), 'rock'],
    [('King Crimson', 'Red'), 'rock'],
    [('my bloody valentine', 'Isnt Anything'), 'rock'],
    [('Nirvana', 'Nevermind'), 'rock'],
    [('Nirvana', 'In Utero'), 'rock'],
    [('The Strokes', 'Is This It'), 'rock'],
    [('Joy Division', 'Unknown Pleasures'), 'rock'],
    [('Joy Division', 'Closer'), 'rock'],
    [('Metallica', 'Ride the Lightning'), 'rock'],
    [('Metallica', 'Master of Puppets'), 'rock'],
    [('Metallica', 'Kill Em All'), 'rock'],
    [('Pixies', 'Doolittle'), 'rock'],
    [('Tool', 'Lateralus'), 'rock'],
    [('Tool', 'Ænima'), 'rock'],
    [('Black Sabbath', 'Paranoid'), 'rock'],
    [('Black Sabbath', 'Black Sabbath'), 'rock'],
    [('Black Sabbath', 'Master of Reality'), 'rock'],
    [('The National', 'Boxer'), 'rock'],
    [('Jeff Rosenstock', 'Worry'), 'rock'],
    [('Slint', 'Spiderland'), 'rock'],
    # [('The Beatles', 'Abbey Road'), 'rock'],
    # [('David Bowie', 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars'), 'rock'],
    # [('Talking Heads', 'Remain in Light'), 'rock'],
    # [('Godspeed You! Black Emperor','Lift Your Skinny Fists Like Antennas to Heaven'), 'rock'],


    [('Beach Boys', 'Pet Sounds'), 'pop'],
    # [('Kate Bush', 'Hounds of Love'), 'pop'],
    [('Carly Rae Jepsen', 'Emotion'), 'pop'],
    [('Belle and Sebastian', 'If Youre Feeling Sinister'), 'pop'],
    # [('Bjork', 'Vespertine'), 'pop'],
    [('Taylor Swift', '1989'), 'pop'],
    [('The Beatles', 'Abbey Road'), 'pop'],
    [('David Bowie', 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars'), 'pop'],
    [('Bjork', 'Post'), 'pop'],
    [('Bjork', 'Debut'), 'pop'],
    [('New Order', 'Technique'), 'pop'],
    [('Carly Rae Jepsen', 'Dedicated'), 'pop'],
    [('Taylor Swift', 'Red'), 'pop'],
    [('Lorde', 'Melodrama'), 'pop'],
    [('Carly Rae Jepsen', 'Kiss'), 'pop'],
    [('Carly Rae Jepsen', 'Emotion Side B'), 'pop'],
    [('Carly Rae Jepsen', 'Dedicated'), 'pop'],
    [('LOONA', '[X X]'), 'pop'],
    [('Charli XCX', 'Sucker'), 'pop'],
    [('Lorde', 'Melodrama'), 'pop'],
    [('Dua Lipa', 'Future Nostalgia'), 'pop'],
    [('Olivia Rodrigo', 'Sour'), 'pop'],
    [('Ariana Grande', 'Positions'), 'pop'],
    [('Ariana Grande', 'Sweetener'), 'pop'],
    [('Ariana Grande', 'My Everything'), 'pop'],
    [('Doja Cat', 'Planet Her'), 'pop'],

    [('Kendrick Lamar', 'To Pimp a Butterfly'), 'hip-hop'],
    [('Kendrick Lamar', 'good kid, m.A.A.d city'), 'hip-hop'],
    [('Madvillain', 'Madvillainy'), 'hip-hop'],
    [('MF DOOM', 'MM...FOOD'), 'hip-hop'],
    [('Nas', 'Illmatic'), 'hip-hop'],
    [('Nas', 'Magic'), 'hip-hop'],
    [('Kanye West', 'My Beautiful Dark Twisted Fantasy'), 'hip-hop'],
    [('Kanye West', 'The College Dropout'), 'hip-hop'],
    [('Travis Scott', 'Rodeo'), 'hip-hop'],
    [('Travis Scott', 'Astroworld'), 'hip-hop'],
    [('Playboi Carti', 'Playboi Carti'), 'hip-hop'],
    [('Playboi Carti', 'Die Lit'), 'hip-hop'],
    [('Wu-Tang Clan', 'Enter The Wu-Tang (36 Chambers) [Expanded Edition]'), 'hip-hop'],
    [('GZA', 'Liquid Swords'), 'hip-hop'],
    [('Beastie Boys', 'Pauls Boutique'), 'hip-hop'],
    [('Outkast', 'Aquemini'), 'hip-hop'],
    [('Mos Def', 'Black on Both Sides'), 'hip-hop'],
    [('The Roots', 'Things Fall Apart'), 'hip-hop'],
    [('A Tribe Called Quest', 'The Low End Theory'), 'hip-hop'],
    # [('Death Grips', 'The Money Store'), 'hip-hop'],

    # [('Swans', 'Soundtracks for the Blind'), 'experimental'],
    # [('Xiu Xiu', 'A Promise'), 'experimental'],
    # [('Death Grips', 'The Money Store'), 'experimental'],
    # [('Injury Reserve', 'By the Time I Get to Phoenix'), 'experimental'],
    # [('Lingua Ignota', 'Sinner Get Ready'), 'experimental'],

    [('Aphex Twin', 'Selected Ambient Works 85-92'), 'electronic'],
    [('Aphex Twin', 'Syro'), 'electronic'],
    [('Aphex Twin', 'Selected Ambient Works Volume II'), 'electronic'],
    [('Aphex Twin', '...I Care Because You Do'), 'electronic'],
    [('Aphex Twin', 'drukqs'), 'electronic'],
    [('Sweet Trip', 'Velocity: Design: Comfort'), 'electronic'],
    [('Boards of Canada', 'Geogaddi'), 'electronic'],
    [('Boards of Canada', 'Music Has the Right to Children'), 'electronic'],
    [('Boards of Canada', 'The Campfire Headphase'), 'electronic'],
    [('Burial', 'Untrue'), 'electronic'],
    [('Burial', 'Burial'), 'electronic'],
    [('Flying Lotus', 'Cosmogramma'), 'electronic'],
    [('Flying Lotus', 'Los Angeles'), 'electronic'],
    [('M83', 'Dead Cities, Red Seas & Lost Ghosts'), 'electronic'],
    [('C418', 'Minecraft - Volume Alpha'), 'electronic'],
    [('C418', 'Minecraft - Volume Beta'), 'electronic'],
    [('Daft Punk', 'Homework'), 'electronic'],
    [('Daft Punk', 'Discovery'), 'electronic'],
]

tempo_max = 220
loudness_max = -60

# %%
data = []

for album in albums:
    # make a zero array of length genres ex [0, 0, 0, 0, 0, 1]
    # with the 1 indiciating which genre it is
    genre_array = np.zeros(len(genres))
    genre_array[genres.index(album[1])] = 1

    results = sp.search(q=f'artist:{album[0][0]} album:{album[0][1]}', type='album')
    album_id = results['albums']['items'][0]['id']
    tracks = sp.album_tracks(album_id)['items']

    for track in tracks:
        track_id = track['id']
        f = sp.audio_features(track_id)[0]
        song_data = np.array([
            f['danceability'], 
            f['energy'], 
            f['loudness']/loudness_max, 
            f['speechiness'], 
            f['acousticness'], 
            f['instrumentalness'], 
            f['liveness'], 
            f['valence'], 
            f['tempo']/tempo_max
        ])
        data.append((song_data, genre_array))

# %%
print(data[5])

with open('data', 'wb') as f: 
    pickle.dump(data, f)
# Out:
# (array([0.547     , 0.38      , 0.15868333, 0.0282    , 0.865     ,
#        0.152     , 0.107     , 0.395     , 0.37990455]), array([1., 0., 0., 0., 0.]))

# %%
with open('data', 'rb') as f: 
    data = pickle.load(f) 

np.random.shuffle(data)
print(data[:5])

print(len(data))

loudness = [d[0][2] for d in data]
print('highest loudness', max(loudness))

tempo = [d[0][8] for d in data]
print('highest tempo', max(tempo))
# Out:
# [(array([0.757     , 0.514     , 0.14541667, 0.264     , 0.0165    ,
#        0.742     , 0.0885    , 0.214     , 0.62277273]), array([0., 0., 0., 0., 1.])), (array([0.689     , 0.774     , 0.09706667, 0.0608    , 0.123     ,
#        0.        , 0.157     , 0.525     , 0.49795909]), array([0., 0., 1., 0., 0.])), (array([0.201     , 0.888     , 0.09151667, 0.0707    , 0.00267   ,
#        0.0981    , 0.291     , 0.329     , 0.35898636]), array([0., 1., 0., 0., 0.])), (array([0.449     , 0.768     , 0.167     , 0.0288    , 0.00186   ,
#        0.77      , 0.165     , 0.519     , 0.48869091]), array([0., 1., 0., 0., 0.])), (array([0.753     , 0.476     , 0.33625   , 0.052     , 0.91      ,
#        0.833     , 0.0552    , 0.663     , 0.59095455]), array([0., 0., 0., 0., 1.]))]
# 1681
# highest loudness 1.0
# highest tempo 0.9909318181818182

# %%
model = nn.Sequential(
  nn.Linear(9, 128),
  nn.ReLU(),
  nn.Linear(128, 128),
  nn.ReLU(),
  nn.Linear(128, 5),
  nn.Softmax(-1)
)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1)

# %%
for epoch in range(1, 21):
  losses = []
  for x, y in data:
    x = torch.tensor(x).reshape(9).float()
    y = torch.tensor(y).reshape(5).float()

    guess = model(x)
    # print(x, y, guess)

    loss = nn.functional.huber_loss(guess, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


    losses.append(loss.item())
  if epoch % 5 == 0:
    print("LOSS", np.mean(losses))
# Out:
# LOSS 0.04686216319379338
# LOSS 0.04256488871933584
# LOSS 0.04107888989712504
# LOSS 0.04015364878877547

# %%
def get_genre(name, artist):
  results = sp.search(q="track:" + name + " artist:" + artist, type="track")
  track_id = results['tracks']['items'][0]['id']

  f = sp.audio_features(track_id)[0]
  song = np.array([
      f['danceability'], 
      f['energy'], 
      f['loudness']/loudness_max, 
      f['speechiness'], 
      f['acousticness'], 
      f['instrumentalness'], 
      f['liveness'], 
      f['valence'], 
      f['tempo']/tempo_max
  ])
  song = torch.tensor(song).reshape(9).float()

  t = model(song)
  value = (t == max(t)).nonzero(as_tuple=True)[0].detach()

  to_return = (f'{name} by {artist} is {genres[value]} ({round(int(10000*max(t)))/100}% confidence)\n')
  
  if max(t) < .6:
    t_list = list(t)
    t_list[t_list.index(max(t_list))] = torch.tensor(0)
    secondary_genre = genres[t_list.index(max(t_list))]
    sum = 0
    for val in t_list:
      sum += val.item()
    secondary_confidence = max(t_list) / sum
    if secondary_confidence > .5:
      to_return += f'Secondary genre: {secondary_genre} ({round(int(10000*secondary_confidence))/100}% confidence)\n'

  return to_return

# %%
test_songs = [
  ('Pink Moon', 'Nick Drake'),
  # ('Fools Errand', 'Fleet Foxes'),
  # ('Oxford Town', 'Bob Dylan'),
  ('Wesleys Theory', 'Kendrick Lamar'),
  # ('Aquemini', 'Outkast'),
  # ('Runaway', 'Kanye West'),
  # ('Blank Space', "Taylor Swift"),
  ('Gimmie Love', "Carly Rae Jepsen"),
  # ('Shape of You', 'Ed Sheeran'),
  ('Green Calx', 'Aphex Twin'),
  # ('Tekka', 'Sweet Trip'),
  # ('Roygbiv', 'Boards of Canada'),
  ('Let Down', 'Radiohead'),
  ('Chicago', 'Sufjan Stevens'),
  ('Five Years', 'David Bowie'),
]
tests = [get_genre(x[0], x[1]) for x in test_songs]
for test in tests:
  print(test)
# Out:
# Pink Moon by Nick Drake is folk (66.13% confidence)
#
# Wesleys Theory by Kendrick Lamar is hip-hop (74.59% confidence)
#
# Gimmie Love by Carly Rae Jepsen is pop (73.18% confidence)
#
# Green Calx by Aphex Twin is electronic (47.45% confidence)
# Secondary genre: rock (85.66% confidence)
#
# Let Down by Radiohead is rock (89.99% confidence)
#
# Chicago by Sufjan Stevens is folk (49.78% confidence)
# Secondary genre: pop (68.43% confidence)
#
# Five Years by David Bowie is pop (39.36% confidence)
# Secondary genre: rock (51.02% confidence)

# %%
print('Enter song:')
song = input()

print('Enter artist:')
artist = input()

try:
  print(get_genre(song, artist))
except Exception as e:
  print('Could not find the song!')
  # print(e)
# Out:
# Enter song:
# Enter artist:
# The Sky is Fallin by Queens of the Stone Age is rock (72.22% confidence)
